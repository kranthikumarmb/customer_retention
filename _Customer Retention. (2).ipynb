# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r'D:\customer_retention_file.xlsx')
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
df.dtypes.value_counts()
# Out:
# int64     46
# object    25
# dtype: int64

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
df.head(15)
# Out:
#     1Gender of respondent  2 How old are you?   \
# 0                       0                    3
# 1                       1                    2
# 2                       1                    2
# 3                       0                    2
# 4                       1                    2
# 5                       1                    3
# 6                       0                    4
# 7                       0                    4
# 8                       1                    1
# 9                       1                    3
# 10                      0                    3
# 11                      1                    4
# 12                      1                    5
# 13                      1                    3
# 14                      1                    2
#
#    3 Which city do you shop online from?  \
# 0                                  Delhi
# 1                                  Delhi
# 2                          Greater Noida
# ...

# %%
df.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %%
# comparing the two columns depends on their information of similar product and content on the website
plt.figure(figsize=(5,5))
sns.barplot(x = '18 The content on the website must be easy to read and understand',y = '19 Information on similar product to the one highlighted  is important for product comparison', data =df)
plt.show()

# %%
# comparing 20 Complete information on listed seller and product being offered is important for purchase decision. and 21 All relevant information on listed products must be stated clearly
plt.figure(figsize=(5,5))
sns.scatterplot(x = '20 Complete information on listed seller and product being offered is important for purchase decision.',y = '21 All relevant information on listed products must be stated clearly', data =df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x = '22 Ease of navigation in website',y = '23 Loading and processing speed', data =df)
plt.show()

# %%
sns.countplot(x='24 User friendly Interface of the website',data=df)
# Out:
# <AxesSubplot:xlabel='24 User friendly Interface of the website', ylabel='count'>

# %%
sns.catplot(x='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',y='25 Convenient Payment methods',data=df)

# %%
# checking for the outliers
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
c=df.corr()
c
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                              -0.034449
# 4 What is the Pin Code of where you shop online...               0.260696
# 5 Since How Long You are Shopping Online ?                      -0.046005
# 6 How many times you have made an online purcha...               0.076121
# 7 How do you access the internet while shopping...              -0.200974
# 8 Which device do you use to access the online ...              -0.241847
# 9 What is the screen size of your mobile device...              -0.058760
# 10 What is the operating system (OS) of your de...              -0.038207
# 11 What browser do you run on your device to ac...              -0.116712
# 12 Which channel did you follow to arrive at yo...              -0.166694
# 13 After first visit, how do you reach the onli...               0.104118
# ...

# %%
sns.violinplot(x='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',y='30 Online shopping gives monetary benefit and discounts',data=df)
# Out:
# <AxesSubplot:xlabel='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)', ylabel='30 Online shopping gives monetary benefit and discounts'>

# %%
df.plot.hexbin(x='31 Enjoyment is derived from shopping online',y='32 Shopping online is convenient and flexible',gridsize=15)
# Out:
# <AxesSubplot:xlabel='31 Enjoyment is derived from shopping online', ylabel='32 Shopping online is convenient and flexible'>

# %%
df.plot.pie(x='35 Displaying quality Information on the website improves satisfaction of customers',y='33 Return and replacement policy of the e-tailer is important for purchase decision',figsize=(10,12))
# Out:
# <AxesSubplot:ylabel='33 Return and replacement policy of the e-tailer is important for purchase decision'>

# %%
sns.violinplot(x='36 User derive satisfaction while shopping on a good quality website or application',y='37 Net Benefit derived from shopping online can lead to users satisfaction',data=df)
# Out:
# <AxesSubplot:xlabel='36 User derive satisfaction while shopping on a good quality website or application', ylabel='37 Net Benefit derived from shopping online can lead to users satisfaction'>

# %%
sns.barplot(x='39 Offering a wide variety of listed product in several category',y='38 User satisfaction cannot exist without trust',data=df)
# Out:
# <AxesSubplot:xlabel='39 Offering a wide variety of listed product in several category', ylabel='38 User satisfaction cannot exist without trust'>

# %%
plt.figure(figsize=(5,5))
sns.catplot(x = '40 Provision of complete and relevant product information',y = '41 Monetary savings', data =df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x = '42 The Convenience of patronizing the online retailer',y = '43 Shopping on the website gives you the sense of adventure', data =df)
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(45,52))
# Out:
# 1Gender of respondent                                                                                                                                                                                                    AxesSubplot(0.125,0.865688;0.0124598x0.0143123)
# 2 How old are you?                                                                                                                                                                                                     AxesSubplot(0.139952,0.865688;0.0124598x0.0143...
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  AxesSubplot(0.154904,0.865688;0.0124598x0.0143...
# ...

# %%
plt.figure(figsize=(17,19))
sns.heatmap(c,cbar=True,square=True,fmt='.1f',annot=True,annot_kws={'size':8},cmap='Accent')
plt.show()

# %%
plt.scatter(df['46 Shopping on the website helps you fulfill certain roles'],df['47 Getting value for money spent'])
plt.show()

# %%
from scipy.stats import zscore 
import numpy as np

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    int64
# ...

# %%
df1=df.describe()
df1
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %%
# checking the zscore value
from scipy.stats import zscore
import numpy as n
z=np.abs(zscore(df1))
z
# Out:
#        1Gender of respondent  2 How old are you?   \
# count               2.645726             2.645470
# mean                0.377086             0.375185
# std                 0.379314             0.396680
# min                 0.384624             0.397429
# 25%                 0.384624             0.386075
# 50%                 0.373359             0.374721
# 75%                 0.373359             0.363367
# max                 0.373359             0.352013
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                           1.268944
# mean                                            0.169699
# std                                             0.352594
# min                                             0.551970
# 25%                                             0.473504
# 50%                                             0.044500
# 75%                                             0.044546
# ...

# %%
threshold=3
df1.where(z>3)
# Out:
#        1Gender of respondent  2 How old are you?   \
# count                    NaN                  NaN
# mean                     NaN                  NaN
# std                      NaN                  NaN
# min                      NaN                  NaN
# 25%                      NaN                  NaN
# 50%                      NaN                  NaN
# 75%                      NaN                  NaN
# max                      NaN                  NaN
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                                NaN
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# ...

# %%
# saving the data by removing the outliers
df_new=df1[(z<3).all(axis=1)]
df_new
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df_new.shape
# Out:
# (8, 46)

# %%
df1.shape
# Out:
# (8, 46)
